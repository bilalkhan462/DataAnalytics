# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
# Clean Data
cars.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
cars['Cylinders'].fillna(cars['Cylinders'].mean(), inplace = True)

# %%
cars.head(3)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0

# %%
cars.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
# What are the different types of make and their counts
cars['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
# How many makes there are
len(cars['Make'].value_counts())
# Out:
# 38

# %%
# Show All the records whereOrigin is Asia or Europe
cars[cars['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945.0
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755.0
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0
# 426  Volvo                      V40  Wagon  Europe      Front  26135.0
# 427  Volvo                     XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Drop the row where weight of vehicle is greater than 4000
cars['Weight'] > 4000
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 423    False
# 424    False
# 425    False
# 426    False
# 427    False
# Name: Weight, Length: 428, dtype: bool

# %%
cars[cars['Weight']>4000]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 401  Volkswagen                      Touareg V6     SUV  Europe        All
# 411  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 412  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 415  Volkswagen                       Passat W8   Wagon  Europe      Front
# 416       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
cars.drop(cars[cars['Weight'] > 4000].index, inplace = True)

# %%
cars.head()
# Out:
#     Make                    Model   Type Origin DriveTrain     MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura                   TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  46100.0  41100.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
# 5         3.5        6.0       225.0      18.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# ...

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  46100.0
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0
# 426  Volvo                      V40  Wagon  Europe      Front  26135.0
# 427  Volvo                     XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# Inccrease all the values of "MPG_City" column by 3.
cars['MPG_City'] = cars['MPG_City'].apply(lambda x: x+3)

# %%
cars.head()
# Out:
#     Make                    Model   Type Origin DriveTrain     MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura                   TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  46100.0  41100.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
# 5         3.5        6.0       225.0      21.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(cars['Type'],cars['Weight'])
plt.title('Type vs Weight')
plt.xlabel('Type')
plt.ylabel('Weight per Type')
plt.show()
